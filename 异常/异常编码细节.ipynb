# %% [markdown]
#  #### else语句只在try代码块没有异常的时候执行

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### demo

# %%
sep = '-'*32 + '\n'

# %%
print sep + 'Exception raised and caught'
try:
    x = 'spam'[99]
except IndexError:
    print 'except run'
finally:
    print 'finally run'
print 'after run'
#########################################################
print sep + 'No exception raised'
try:
    x = 'spam'[3]
except IndexError:
    print 'except run'
finally:
    print 'finally run'
print 'after run'
#########################################################
print sep + 'No exception raised ,With else'
try:
    x = 'spam'[3]
except IndexError:
    print 'except run'
else:
    print 'else run'
finally:
    print 'finally run'
print 'after run'
#########################################################
print sep + 'Exception raised but not caught'
try:
    x = 1/0
except IndexError:
    print 'except run'
finally:
    print 'finally run'
print 'after run'
# Out:
# --------------------------------
# Exception raised and caught
# except run
# finally run
# after run
# --------------------------------
# No exception raised
# finally run
# after run
# --------------------------------
# No exception raised ,With else
# else run
# finally run
# after run
# --------------------------------
# Exception raised but not caught
# finally run
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-f5fdfed9728b> in <module>()
#      30 print sep + 'Exception raised but not caught'
#      31 try:
# ---> 32     x = 1/0
#      33 except IndexError:
#      34     print 'except run'
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# #### raise 显示的触发异常

# %% [markdown]
# #### 利用raise传递异常

# %%
try:
    raise IndexError('spam')
except IndexError:
    print 'get exception'
    raise
# Out:
# get exception
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-2bf081ecd69b> in <module>()
#       1 try:
# ----> 2     raise IndexError('spam')
#       3 except IndexError:
#       4     print 'get exception'
#       5     raise
#
# IndexError: spam

# %% [markdown]
# #### assert几乎都是用来收集用户定义的约束条件，而不是捕捉内在的程序设计错误

# %%
def f(x):
    assert x < 0, 'x must be negative'
    return x**2

f(1)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-e4b4f3815f75> in <module>()
#       3     return x**2
#       4
# ----> 5 f(1)
#
# <ipython-input-10-e4b4f3815f75> in f(x)
#       1 def f(x):
# ----> 2     assert x < 0, 'x must be negative'
#       3     return x**2
#       4
#       5 f(1)
#
# AssertionError: x must be negative

# %%
f(-1)
# Out:
# 1

# %% [markdown]
# #### with/as 语句的设计是作为常见try/finally用法模式的替代方案。
# #### 就像try/finally语句，with/as语句也是用于定义必须执行的终止和清理行为，无论处理步骤中是否发生异常
